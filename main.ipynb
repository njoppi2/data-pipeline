# %%
from dags.data_engineering_pipeline import extract_from_postgres, extract_from_csv, load_into_final_database, execute_query
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Step 1
# Write data to local disk

# %%
extract_from_postgres()
extract_from_csv()
# Out:
# Data extracted from table 'suppliers' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/suppliers/2023-08-22/suppliers.csv
# Data extracted from table 'employees' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/employees/2023-08-22/employees.csv
# Data extracted from table 'shippers' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/shippers/2023-08-22/shippers.csv
# Data extracted from table 'categories' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/categories/2023-08-22/categories.csv
# Data extracted from table 'employee_territories' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/employee_territories/2023-08-22/employee_territories.csv
# Data extracted from table 'region' and saved to /home/njoppi2/projetos/pessoal/data-pipeline/dags/../data/postgres/region/2023-08-22/region.csv
# ...

# %% [markdown]
# # Step 2
# Load data to final database

# %%
load_into_final_database()
# Out:
# Didn't create database: CREATE DATABASE cannot run inside a transaction block
#
# Data loaded into table 'suppliers' in the target database.
# Data loaded into table 'employees' in the target database.
# Data loaded into table 'shippers' in the target database.
# Data loaded into table 'categories' in the target database.
# Data loaded into table 'employee_territories' in the target database.
# Data loaded into table 'region' in the target database.
# Data loaded into table 'customer_demographics' in the target database.
# Data loaded into table 'us_states' in the target database.
# Data loaded into table 'products' in the target database.
# Data loaded into table 'territories' in the target database.
# Data loaded into table 'customer_customer_demo' in the target database.
# Data loaded into table 'customers' in the target database.
# Data loaded into table 'orders' in the target database.
# Data loaded into table 'order_details' in the target database.

# %% [markdown]
# # Final query
# Show the orders and its details

# %%
execute_query('''
    SELECT *
    FROM public.orders AS o
    LEFT JOIN public.order_details AS od ON o.order_id = od.order_id
    LIMIT 20
''')
# Out:
#     order_id customer_id  employee_id  order_date required_date shipped_date  \
# 0      10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 1      10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 2      10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 3      10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 4      10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 5      10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 6      10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 7      10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 8      10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# 9      10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# 10     10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# ...
